# %% [markdown]
# <a href="https://colab.research.google.com/github/ThailanRg/engenharia-de-ia/blob/main/google-colab-egenieria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get('GEMINI_API_KEY')

# %%
from google import genai
client = genai.Client()

# %%
resposta = client.models.generate_content(model = "gemini-2.5-flash", contents="o que é IA")
print(resposta.text)
# Out:
# **IA (Inteligência Artificial)** é um campo da ciência da computação dedicado a criar máquinas ou programas de computador capazes de simular a inteligência humana. O objetivo é permitir que sistemas pensem, aprendam, resolvam problemas, tomem decisões e até mesmo compreendam e interajam com o mundo de forma autônoma ou semi-autônoma.
#
# Em termos mais simples, a IA busca fazer com que computadores e softwares atuem como se tivessem capacidade cognitiva humana.
#
# **Principais Capacidades da IA:**
#
# *   **Aprendizado (Machine Learning):** A capacidade de aprender com dados, identificar padrões e tomar decisões ou fazer previsões sem ser explicitamente programada para cada tarefa específica.
# *   **Raciocínio:** A habilidade de usar regras, lógica e informações para tirar conclusões e resolver problemas.
# *   **Percepção:** A capacidade de "sentir" o ambiente através de dados (visão computacional para imagens, processamento de linguagem natural para texto/voz) e interpretá-los.
# ...

# %%
chat = client.chats.create(model = "gemini-2.5-flash")

# %%
resposta = chat.send_message("o que é amor")
print
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""O amor é uma das emoções e experiências mais complexas, profundas e multifacetadas da existência humana. Não há uma única definição universalmente aceita, pois ele se manifesta e é percebido de maneiras muito pessoais, culturais e contextuais.
#
# No entanto, em sua essência, o amor pode ser descrito como um **sentimento intenso de afeto, profunda conexão e cuidado** por algo ou alguém. É uma força poderosa que impulsiona o desejo de bem-estar, a felicidade e a união.
#
# Vamos desdobrar o que o amor geralmente envolve:
#
# 1.  **Afeição e Cuidado:** Um desejo genuíno de ver o outro feliz, seguro e bem. Envolve proteger, nutrir e apoiar.
# 2.  **Conexão e Vínculo:** Uma sensação de união profunda com o outro, como se partes de vocês estivessem interligadas.
# ...

# %% [markdown]
# # Estruturas de repetição

# %%
n = 1
while n <= 2:
   print("*")
   n = n + 1
# Out:
# *
# *
